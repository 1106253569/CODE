# %%
import pandas as pd
from pyecharts import options as opts
from pyecharts.globals import ThemeType
from pyecharts.charts import Bar, Grid, Line, Pie, Map

dataset = pd.read_excel("city.xls", header=0, index_col=0)
y_value1 = [int(value) for value in dataset.loc["超市A"].values]
y_value2 = [int(value) for value in dataset.loc["超市B"].values]

# %%
bar = (
    Bar().add_xaxis(list(dataset.columns.values))  # type: ignore
    .add_yaxis("超市A", y_value1)  # type: ignore
    .add_yaxis("超市B", y_value2)  # type: ignore
    .reversal_axis()
    .set_series_opts(
        label_opts=opts.LabelOpts(position="right"),
        markpoint_opts=opts.MarkPointOpts(data=[
            opts.MarkPointItem(type_="min", name="最小值"),
            opts.MarkPointItem(type_="max", name="最大值"),
            opts.MarkPointItem(type_="average", name="平均值"),
        ]))
    .set_global_opts(title_opts=opts.TitleOpts(title="货品销售情况", subtitle="A和B超市"))
    )
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="449a78e5e2824f18b23f354c1064a11c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_449a78e5e2824f18b23f354c1064a11c = echarts.init(
#                     document.getElementById('449a78e5e2824f18b23f354c1064a11c'), 'white', {renderer: 'canvas'});
#                 var option_449a78e5e2824f18b23f354c1064a11c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8d85\u5e02A",
#             "legendHoverLink": true,
#             "data": [
#                 125,
#                 94,
#                 55,
#                 101,
#                 114,
#                 30,
#                 105,
#                 45,
#                 29
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u8d85\u5e02B",
#             "legendHoverLink": true,
#             "data": [
#                 57,
#                 72,
#                 64,
#                 68,
#                 35,
#                 45,
#                 49,
#                 30,
#                 18
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8d85\u5e02A",
#                 "\u8d85\u5e02B"
#             ],
#             "selected": {
#                 "\u8d85\u5e02A": true,
#                 "\u8d85\u5e02B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u96ea\u82b1",
#                 "\u9752\u5c9b",
#                 "\u71d5\u4eac",
#                 "\u767e\u5a01",
#                 "\u54c8\u5c14\u6ee8",
#                 "\u73e0\u6c5f",
#                 "\u5609\u58eb\u4f2f",
#                 "\u96ea\u6d25",
#                 "\u84dd\u5e26"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u8d27\u54c1\u9500\u552e\u60c5\u51b5",
#             "subtext": "A\u548cB\u8d85\u5e02",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_449a78e5e2824f18b23f354c1064a11c.setOption(option_449a78e5e2824f18b23f354c1064a11c);
#         });
#     </script>

# %%
bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.CHALK))
    .add_xaxis(list(dataset.columns.values)[0:6])  # type: ignore
    .add_yaxis("超市A", y_value1[0:6])  # type: ignore
    .add_yaxis("超市B", y_value2[0:6])  # type: ignore
    .set_series_opts(
        label_opts=opts.LabelOpts(position="right"),
        markpoint_opts=opts.MarkPointOpts(data=[
            opts.MarkPointItem(type_="min", name="最小值"),
            opts.MarkPointItem(type_="max", name="最大值"),
            opts.MarkPointItem(type_="average", name="平均值"),
        ])
        )
    .set_global_opts(
            title_opts=opts.TitleOpts(title="货品销售情况", subtitle="A和B超市"))
    )
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk'
#         }
#     });
# </script>
#
#         <div id="b013248ae1684a8f9806d364bdc2196f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'chalk'], function(echarts) {
#                 var chart_b013248ae1684a8f9806d364bdc2196f = echarts.init(
#                     document.getElementById('b013248ae1684a8f9806d364bdc2196f'), 'chalk', {renderer: 'canvas'});
#                 var option_b013248ae1684a8f9806d364bdc2196f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8d85\u5e02A",
#             "legendHoverLink": true,
#             "data": [
#                 125,
#                 94,
#                 55,
#                 101,
#                 114,
#                 30
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u8d85\u5e02B",
#             "legendHoverLink": true,
#             "data": [
#                 57,
#                 72,
#                 64,
#                 68,
#                 35,
#                 45
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8d85\u5e02A",
#                 "\u8d85\u5e02B"
#             ],
#             "selected": {
#                 "\u8d85\u5e02A": true,
#                 "\u8d85\u5e02B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u96ea\u82b1",
#                 "\u9752\u5c9b",
#                 "\u71d5\u4eac",
#                 "\u767e\u5a01",
#                 "\u54c8\u5c14\u6ee8",
#                 "\u73e0\u6c5f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u8d27\u54c1\u9500\u552e\u60c5\u51b5",
#             "subtext": "A\u548cB\u8d85\u5e02",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b013248ae1684a8f9806d364bdc2196f.setOption(option_b013248ae1684a8f9806d364bdc2196f);
#         });
#     </script>

# %%
line = (
    Line().add_xaxis(list(dataset.columns.values))  # type: ignore
    .add_yaxis("超市A", y_value1)  # type: ignore
    .add_yaxis("超市B", y_value2)  # type: ignore
    .set_series_opts(
        label_opts=opts.LabelOpts(position="right"),
        markpoint_opts=opts.MarkPointOpts(data=[
            opts.MarkPointItem(type_="min", name="最小值"),
            opts.MarkPointItem(type_="max", name="最大值"),
            opts.MarkPointItem(type_="average", name="平均值"),
        ]))
    .set_global_opts(
            title_opts=opts.TitleOpts(title="货品销售情况", subtitle="A和B超市")))

bar = (
    Bar().add_xaxis(list(dataset.columns.values))  # type: ignore
    .add_yaxis("超市A", y_value1)  # type: ignore
    .add_yaxis("超市B", y_value2)  # type: ignore
    .set_series_opts(
        label_opts=opts.LabelOpts(position="right"),
        markpoint_opts=opts.MarkPointOpts(data=[
            opts.MarkPointItem(type_="min", name="最小值"),
            opts.MarkPointItem(type_="max", name="最大值"),
            opts.MarkPointItem(type_="average", name="平均值"),
        ]))
    .set_global_opts(
            title_opts=opts.TitleOpts(title="货品销售情况", subtitle="A和B超市")))

grid = (
        Grid()
        .add(line, grid_opts=opts.GridOpts(pos_right='55%'))
        .add(bar, grid_opts=opts.GridOpts( pos_left='55%'))
        
    )
grid.render_notebook()  # type: ignore
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="27bad228ec954219865ba5580723e456" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_27bad228ec954219865ba5580723e456 = echarts.init(
#                     document.getElementById('27bad228ec954219865ba5580723e456'), 'white', {renderer: 'canvas'});
#                 var option_27bad228ec954219865ba5580723e456 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u8d85\u5e02A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u96ea\u82b1",
#                     125
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     94
#                 ],
#                 [
#                     "\u71d5\u4eac",
#                     55
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     101
#                 ],
#                 [
#                     "\u54c8\u5c14\u6ee8",
#                     114
#                 ],
#                 [
#                     "\u73e0\u6c5f",
#                     30
#                 ],
#                 [
#                     "\u5609\u58eb\u4f2f",
#                     105
#                 ],
#                 [
#                     "\u96ea\u6d25",
#                     45
#                 ],
#                 [
#                     "\u84dd\u5e26",
#                     29
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u8d85\u5e02B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u96ea\u82b1",
#                     57
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     72
#                 ],
#                 [
#                     "\u71d5\u4eac",
#                     64
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     68
#                 ],
#                 [
#                     "\u54c8\u5c14\u6ee8",
#                     35
#                 ],
#                 [
#                     "\u73e0\u6c5f",
#                     45
#                 ],
#                 [
#                     "\u5609\u58eb\u4f2f",
#                     49
#                 ],
#                 [
#                     "\u96ea\u6d25",
#                     30
#                 ],
#                 [
#                     "\u84dd\u5e26",
#                     18
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u8d85\u5e02A",
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "legendHoverLink": true,
#             "data": [
#                 125,
#                 94,
#                 55,
#                 101,
#                 114,
#                 30,
#                 105,
#                 45,
#                 29
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]

# %%
rose = (
    Pie()
    .add(
        "",
        data_pair=[list(z) for z in zip(list(dataset.columns.values), y_value1)],  # type: ignore
        radius=["10%", "30%"],
        center=["30%", "50%"],
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=True),
    )
    .add(
        "",
        data_pair=[list(z) for z in zip(list(dataset.columns.values), y_value1)],  # type: ignore
        radius=["10%", "30%"],
        center=["75%", "50%"],
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=True),
    )   
    
    .set_global_opts(title_opts=opts.TitleOpts(title="超市A销售情况"),
                    legend_opts=opts.LegendOpts(orient="vertical", pos_top="5%", pos_left="0%"),)
    #设置数据标签格式
    .set_series_opts(
        label_opts=opts.LabelOpts(formatter="{b}:{c}({d}%)"))
)
rose.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f3fbc3794c434dfd870687ae6408e420" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f3fbc3794c434dfd870687ae6408e420 = echarts.init(
#                     document.getElementById('f3fbc3794c434dfd870687ae6408e420'), 'white', {renderer: 'canvas'});
#                 var option_f3fbc3794c434dfd870687ae6408e420 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u96ea\u82b1",
#                     "value": 125
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 94
#                 },
#                 {
#                     "name": "\u71d5\u4eac",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 101
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": 114
#                 },
#                 {
#                     "name": "\u73e0\u6c5f",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5609\u58eb\u4f2f",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u96ea\u6d25",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u84dd\u5e26",
#                     "value": 29
#                 }
#             ],
#             "radius": [
#                 "10%",
#                 "30%"
#             ],
#             "center": [
#                 "30%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}:{c}({d}%)"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u96ea\u82b1",
#                     "value": 125
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 94
#                 },
#                 {
#                     "name": "\u71d5\u4eac",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 101
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": 114
#                 },
#                 {
#                     "name": "\u73e0\u6c5f",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5609\u58eb\u4f2f",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u96ea\u6d25",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u84dd\u5e26",
#                     "value": 29
#                 }
#             ],
#             "radius": [
#                 "10%",
#                 "30%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}:{c}({d}%)"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u96ea\u82b1",
#                 "\u9752\u5c9b",
#                 "\u71d5\u4eac",
#                 "\u767e\u5a01",
#                 "\u54c8\u5c14\u6ee8",
#                 "\u73e0\u6c5f",
#                 "\u5609\u58eb\u4f2f",
#                 "\u96ea\u6d25",
#                 "\u84dd\u5e26"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "5%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u8d85\u5e02A\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f3fbc3794c434dfd870687ae6408e420.setOption(option_f3fbc3794c434dfd870687ae6408e420);
#         });
#     </script>

# %%
import random

city = ["济南市","济宁市","青岛市","淄博市","枣庄市","德州市","东营市","烟台市","潍坊市","威海市","泰安市","临沂市","聊城市","菏泽市","滨州市","日照市","莱芜市"]
prov_city=[city[i] for i in random.sample(range(0, len(city)), 5)]
data_prov_city = [(i, random.randint(16, 21)) for i in prov_city]
province_city = (
    Map()
    .add("", data_prov_city, "山东")
    .set_global_opts(title_opts=opts.TitleOpts(title="山东省地图"),
                     visualmap_opts=opts.VisualMapOpts(min_=15, max_=25, is_piecewise=True))
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True))
    )
province_city.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '山东':'https://assets.pyecharts.org/assets/maps/shandong'
#         }
#     });
# </script>
#
#         <div id="2b7873e87dd44904b901c87d94eea77e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '山东'], function(echarts) {
#                 var chart_2b7873e87dd44904b901c87d94eea77e = echarts.init(
#                     document.getElementById('2b7873e87dd44904b901c87d94eea77e'), 'white', {renderer: 'canvas'});
#                 var option_2b7873e87dd44904b901c87d94eea77e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u5c71\u4e1c",
#             "data": [
#                 {
#                     "name": "\u70df\u53f0\u5e02",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u6ee8\u5dde\u5e02",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u4e1c\u8425\u5e02",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u65e5\u7167\u5e02",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u83cf\u6cfd\u5e02",
#                     "value": 17
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5c71\u4e1c\u7701\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 15,
#         "max": 25,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_2b7873e87dd44904b901c87d94eea77e.setOption(option_2b7873e87dd44904b901c87d94eea77e);
#         });
#     </script>
